# %% [markdown]
# <a href="https://colab.research.google.com/github/mahadikprasad15/Probes-generalization-across-contexts-and-capabilities/blob/main/Probe_Generalization_across_contexts_and_capabilities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from huggingface_hub import login
login()

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/mahadikprasad15/Probes-generalization-across-contexts-and-capabilities.git
# %cd Probes-generalization-across-contexts-and-capabilities/

# %%
# %cd /content/drive/MyDrive/Probes-generalization-across-contexts-and-capabilities
# !git pull origin main

# %%
# !pip install cerebras-cloud-sdk

# %%
# !python main.py \
  --base_dir "/content/drive/MyDrive/Probes-generalization-across-contexts-and-capabilities" \
  --steps generate \
  --n_samples 100 \
  --use_api \
  --api_provider cerebras\
  --api_key "csk-mhfprn3kttt2vp34ct22936v8cef4km5ewhnwc3tkptmk6eh" \
  --api_model "llama3.1-8b"\
  --batch_size 5

# %%
# !python main.py \
  --base_dir "/content/drive/MyDrive/Probes-generalization-across-contexts-and-capabilities" \
  --steps extract train evaluate \
  --model "meta-llama/Llama-3.2-1B-Instruct"
